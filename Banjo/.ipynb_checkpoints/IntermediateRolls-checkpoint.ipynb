# %%
#the following code checks to see if two values appear twice in a row
def twice_in_a_row(l):
    repeat_count = []
    for i in range(1,len(l)):
        if l[i-1]==l[i]:
            repeat_count.append(1)
        else:
            repeat_count.append(0)
    if sum(repeat_count)>0:
        return True
    else:
        return False

# %%
import itertools
intermediate_rolls = []
rolls = list(itertools.product('IMT',repeat = 8))
for roll in rolls:
    lroll = list(roll)
    if not twice_in_a_row(lroll):
        intermediate_rolls.append(roll)

# %%
#create a roll dictionary with all the intermediate rolls
roll_dict = {}
keys = range(len(intermediate_rolls))
for roll in keys:
    roll_dict[roll] = intermediate_rolls[roll]
print(roll_dict)
# Out:
# {0: ('I', 'M', 'I', 'M', 'I', 'M', 'I', 'M'), 1: ('I', 'M', 'I', 'M', 'I', 'M', 'I', 'T'), 2: ('I', 'M', 'I', 'M', 'I', 'M', 'T', 'I'), 3: ('I', 'M', 'I', 'M', 'I', 'M', 'T', 'M'), 4: ('I', 'M', 'I', 'M', 'I', 'T', 'I', 'M'), 5: ('I', 'M', 'I', 'M', 'I', 'T', 'I', 'T'), 6: ('I', 'M', 'I', 'M', 'I', 'T', 'M', 'I'), 7: ('I', 'M', 'I', 'M', 'I', 'T', 'M', 'T'), 8: ('I', 'M', 'I', 'M', 'T', 'I', 'M', 'I'), 9: ('I', 'M', 'I', 'M', 'T', 'I', 'M', 'T'), 10: ('I', 'M', 'I', 'M', 'T', 'I', 'T', 'I'), 11: ('I', 'M', 'I', 'M', 'T', 'I', 'T', 'M'), 12: ('I', 'M', 'I', 'M', 'T', 'M', 'I', 'M'), 13: ('I', 'M', 'I', 'M', 'T', 'M', 'I', 'T'), 14: ('I', 'M', 'I', 'M', 'T', 'M', 'T', 'I'), 15: ('I', 'M', 'I', 'M', 'T', 'M', 'T', 'M'), 16: ('I', 'M', 'I', 'T', 'I', 'M', 'I', 'M'), 17: ('I', 'M', 'I', 'T', 'I', 'M', 'I', 'T'), 18: ('I', 'M', 'I', 'T', 'I', 'M', 'T', 'I'), 19: ('I', 'M', 'I', 'T', 'I', 'M', 'T', 'M'), 20: ('I', 'M', 'I', 'T', 'I', 'T', 'I', 'M'), 21: ('I', 'M', 'I', 'T', 'I', 'T', 'I', 'T'), 22: ('I', 'M', 'I', 'T', 'I', 'T', 'M', 'I'), 23: ('I', 'M', 'I', 'T', 'I', 'T', 'M', 'T'), 24: ('I', 'M', 'I', 'T', 'M', 'I', 'M', 'I'), 25: ('I', 'M', 'I', 'T', 'M', 'I', 'M', 'T'), 26: ('I', 'M', 'I', 'T', 'M', 'I', 'T', 'I'), 27: ('I', 'M', 'I', 'T', 'M', 'I', 'T', 'M'), 28: ('I', 'M', 'I', 'T', 'M', 'T', 'I', 'M'), 29: ('I', 'M', 'I', 'T', 'M', 'T', 'I', 'T'), 30: ('I', 'M', 'I', 'T', 'M', 'T', 'M', 'I'), 31: ('I', 'M', 'I', 'T', 'M', 'T', 'M', 'T'), 32: ('I', 'M', 'T', 'I', 'M', 'I', 'M', 'I'), 33: ('I', 'M', 'T', 'I', 'M', 'I', 'M', 'T'), 34: ('I', 'M', 'T', 'I', 'M', 'I', 'T', 'I'), 35: ('I', 'M', 'T', 'I', 'M', 'I', 'T', 'M'), 36: ('I', 'M', 'T', 'I', 'M', 'T', 'I', 'M'), 37: ('I', 'M', 'T', 'I', 'M', 'T', 'I', 'T'), 38: ('I', 'M', 'T', 'I', 'M', 'T', 'M', 'I'), 39: ('I', 'M', 'T', 'I', 'M', 'T', 'M', 'T'), 40: ('I', 'M', 'T', 'I', 'T', 'I', 'M', 'I'), 41: ('I', 'M', 'T', 'I', 'T', 'I', 'M', 'T'), 42: ('I', 'M', 'T', 'I', 'T', 'I', 'T', 'I'), 43: ('I', 'M', 'T', 'I', 'T', 'I', 'T', 'M'), 44: ('I', 'M', 'T', 'I', 'T', 'M', 'I', 'M'), 45: ('I', 'M', 'T', 'I', 'T', 'M', 'I', 'T'), 46: ('I', 'M', 'T', 'I', 'T', 'M', 'T', 'I'), 47: ('I', 'M', 'T', 'I', 'T', 'M', 'T', 'M'), 48: ('I', 'M', 'T', 'M', 'I', 'M', 'I', 'M'), 49: ('I', 'M', 'T', 'M', 'I', 'M', 'I', 'T'), 50: ('I', 'M', 'T', 'M', 'I', 'M', 'T', 'I'), 51: ('I', 'M', 'T', 'M', 'I', 'M', 'T', 'M'), 52: ('I', 'M', 'T', 'M', 'I', 'T', 'I', 'M'), 53: ('I', 'M', 'T', 'M', 'I', 'T', 'I', 'T'), 54: ('I', 'M', 'T', 'M', 'I', 'T', 'M', 'I'), 55: ('I', 'M', 'T', 'M', 'I', 'T', 'M', 'T'), 56: ('I', 'M', 'T', 'M', 'T', 'I', 'M', 'I'), 57: ('I', 'M', 'T', 'M', 'T', 'I', 'M', 'T'), 58: ('I', 'M', 'T', 'M', 'T', 'I', 'T', 'I'), 59: ('I', 'M', 'T', 'M', 'T', 'I', 'T', 'M'), 60: ('I', 'M', 'T', 'M', 'T', 'M', 'I', 'M'), 61: ('I', 'M', 'T', 'M', 'T', 'M', 'I', 'T'), 62: ('I', 'M', 'T', 'M', 'T', 'M', 'T', 'I'), 63: ('I', 'M', 'T', 'M', 'T', 'M', 'T', 'M'), 64: ('I', 'T', 'I', 'M', 'I', 'M', 'I', 'M'), 65: ('I', 'T', 'I', 'M', 'I', 'M', 'I', 'T'), 66: ('I', 'T', 'I', 'M', 'I', 'M', 'T', 'I'), 67: ('I', 'T', 'I', 'M', 'I', 'M', 'T', 'M'), 68: ('I', 'T', 'I', 'M', 'I', 'T', 'I', 'M'), 69: ('I', 'T', 'I', 'M', 'I', 'T', 'I', 'T'), 70: ('I', 'T', 'I', 'M', 'I', 'T', 'M', 'I'), 71: ('I', 'T', 'I', 'M', 'I', 'T', 'M', 'T'), 72: ('I', 'T', 'I', 'M', 'T', 'I', 'M', 'I'), 73: ('I', 'T', 'I', 'M', 'T', 'I', 'M', 'T'), 74: ('I', 'T', 'I', 'M', 'T', 'I', 'T', 'I'), 75: ('I', 'T', 'I', 'M', 'T', 'I', 'T', 'M'), 76: ('I', 'T', 'I', 'M', 'T', 'M', 'I', 'M'), 77: ('I', 'T', 'I', 'M', 'T', 'M', 'I', 'T'), 78: ('I', 'T', 'I', 'M', 'T', 'M', 'T', 'I'), 79: ('I', 'T', 'I', 'M', 'T', 'M', 'T', 'M'), 80: ('I', 'T', 'I', 'T', 'I', 'M', 'I', 'M'), 81: ('I', 'T', 'I', 'T', 'I', 'M', 'I', 'T'), 82: ('I', 'T', 'I', 'T', 'I', 'M', 'T', 'I'), 83: ('I', 'T', 'I', 'T', 'I', 'M', 'T', 'M'), 84: ('I', 'T', 'I', 'T', 'I', 'T', 'I', 'M'), 85: ('I', 'T', 'I', 'T', 'I', 'T', 'I', 'T'), 86: ('I', 'T', 'I', 'T', 'I', 'T', 'M', 'I'), 87: ('I ...

# %%
Plucked_String = {'T':['g','D','G'],
                 'M':['d','B'],
                 'I':['G','B']}
